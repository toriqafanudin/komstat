# %%
df = read.csv("/kaggle/input/nilaikom/nilai_tugas_komstat_C.csv", sep=";")
df
# Out:
#    Nama                         Uji.t.SPSS One.Way.SPSS Two.Way.SPSS
# 1  Aulia Cahya Pratiwi           68         80          70
# 2  Khairullah                    93          0           0
# 3  Erisa Putri Cahyani           95         95          92
# 4  Marisa Devi Isnaini Arifah   100        100          92
# 5  Arinna Dhiyaa' Nisa Lathifah  60         95           0
# 6  Nurhasanah                    93         95          70
# 7  Meiliya Widiastuti            93         95          70
# 8  Dhita Agustina                98         95          95
# 9  Anggriani Stia Arum           70         85          90
# 10 Dewi Rahmawati               100         95          92
# 11 Zahro Khoirunisa              70         95          87
# 12 Fadila Nur Salsabela          70         95          77
# 13 Malika Mahira                 70         80          82
# 14 Nurma Izzalatuzzahro          70         85          87
# 15 Aulia Diah Safitri            85         85          82
# ...
