# %%
dosen_A = c(73,89,82,43,80,73,66,60,45,93,36,77)
dosen_B = c(88,78,48,91,51,85,74,77,31,78,62,76,96,80,56)
dosen_C = c(68,79,56,91,71,71,87,41,59,68,53,79,15)

shapiro.test(dosen_A)
shapiro.test(dosen_B)
shapiro.test(dosen_C)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  dosen_A
# W = 0.9319, p-value = 0.4006
# 	Shapiro-Wilk normality test
#
# data:  dosen_B
# W = 0.92699, p-value = 0.2459
# 	Shapiro-Wilk normality test
#
# data:  dosen_C
# W = 0.9212, p-value = 0.2604

# %%
label_A = rep('A', times=length(dosen_A))
label_B = rep('B', times=length(dosen_B))
label_C = rep('C', times=length(dosen_C))

nilai = c(dosen_A, dosen_B, dosen_C)
dosen = c(label_A, label_B, label_C)

bartlett.test(nilai, dosen)
# Out:
# 	Bartlett test of homogeneity of variances
#
# data:  nilai and dosen
# Bartlett's K-squared = 0.18879, df = 2, p-value = 0.9099

# %%
summary(aov(nilai ~ dosen))
# Out:
#             Df Sum Sq Mean Sq F value Pr(>F)
# dosen        2    335   167.7   0.465  0.632
# Residuals   37  13350   360.8

# %%
qf(0.95, 2, 37)
# Out:
# [1] 3.251924

# %% [markdown]
# Dapat dilihat bahwa F hitung < F tabel, sehingga dapat disimpulkan bahwa tidak ada perbedaan efektifitas antara ketiga dosen dalam mengajar.
